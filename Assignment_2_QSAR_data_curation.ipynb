# %% [markdown]
# # **AI And Biotechnology/Bioinformatics**
#
# ## **AI and Drug Discovery Course: QSAR Modeling**
# This notebook demonstrates how to collect and preprocess bioactivity data from ChEMBL for QSAR modeling

# %% [markdown]
# # **Part 1: Data Collection & Curation**

# %% [markdown]
# **First we need to connect Google Colab with our Google Drive, so that we can have access to our Google drive within Colab.**
#
# This allows us to:
# * Save datasets
# * Reload data across sessions
# * Organize project files

# %%
from google.colab import drive
drive.mount('/content/gdrive/', force_remount=True)
# Out:
# Mounted at /content/gdrive/

# %% [markdown]
# **Now create "data" folder in our "Colab Notebooks" folder on Google Drive.**

# %%
! mkdir "/content/gdrive/My Drive/Colab Notebooks/data"
# Out:
# mkdir: cannot create directory ‘/content/gdrive/My Drive/Colab Notebooks/data’: File exists

# %% [markdown]
# ## Install and Import Required Libraries
# We install the ChEMBL web service package so that we can retrieve bioactivity data

# %%
# !pip install chembl_webresource_client
# Out:
# Collecting chembl_webresource_client
#   Downloading chembl_webresource_client-0.10.9-py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.12/dist-packages (from chembl_webresource_client) (2.5.0)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.12/dist-packages (from chembl_webresource_client) (2.32.4)
# Collecting requests-cache~=1.2 (from chembl_webresource_client)
#   Downloading requests_cache-1.2.1-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: easydict in /usr/local/lib/python3.12/dist-packages (from chembl_webresource_client) (1.13)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.18.4->chembl_webresource_client) (2026.1.4)
# Requirement already satisfied: attrs>=21.2 in /usr/local/lib/python3.12/dist-packages (from requests-cache~=1.2->chembl_webresource_client) (25.4.0)
# Collecting cattrs>=22.2 (from requests-cache~=1.2->chembl_webresource_client)
#   Downloading cattrs-25.3.0-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests-cache~=1.2->chembl_webresource_client) (4.5.1)
# Collecting url-normalize>=1.4 (from requests-cache~=1.2->chembl_webresource_client)
#   Downloading url_normalize-2.2.1-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: typing-extensions>=4.14.0 in /usr/local/lib/python3.12/dist-packages (from cattrs>=22.2->requests-cache~=1.2->chembl_webresource_client) (4.15.0)
# Downloading chembl_webresource_client-0.10.9-py3-none-any.whl (55 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 kB 2.6 MB/s eta 0:00:00
# Downloading requests_cache-1.2.1-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.4/61.4 kB 5.6 MB/s eta 0:00:00
# Downloading cattrs-25.3.0-py3-none-any.whl (70 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.7/70.7 kB 7.0 MB/s eta 0:00:00
# Downloading url_normalize-2.2.1-py3-none-any.whl (14 kB)
# Installing collected packages: url-normalize, cattrs, requests-cache, chembl_webresource_client
# Successfully installed cattrs-25.3.0 chembl_webresource_client-0.10.9 requests-cache-1.2.1 url-normalize-2.2.1

# %% [markdown]
# # Import Libraries
# * pandas for data handling
# * new_client from chembl for accessing the database

# %%
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# # Step 1: Search for Traget Protein
#
# ## **Target Identification (KRAS)**
# Search ChEMBL for the KRAS target and select the most relevant entry.

# %%
target = new_client.target
target_query = target.search("KRAS")
targets = pd.DataFrame.from_dict(target_query)
targets.head()
# Out:
#   cross_references      organism  \
# 0               []  Homo sapiens
# 1               []  Homo sapiens
# 2               []  Homo sapiens
# 3               []  Homo sapiens
# 4               []  Homo sapiens
#
#                                          pref_name  score  species_group_flag  \
# 0                                      GTPase KRas   19.0               False
# 1                            Protein cereblon-KRAS   19.0               False
# 2  von Hippel-Lindau disease tumor suppressor/KRAS   18.0               False
# 3                                        SOS1-KRAS   18.0               False
# 4                                       PDE6D/KRAS   17.0               False
#
#   target_chembl_id                                  target_components  \
# 0    CHEMBL2189121  [{'accession': 'P01116', 'component_descriptio...
# 1    CHEMBL5483196  [{'accession': 'P01116', 'component_descriptio...
# 2    CHEMBL5169273  [{'accession': 'P01116', 'component_descriptio...
# 3    CHEMBL5465393  [{'accession': 'Q07889', 'component_descriptio...
# 4    CHEMBL4523623  [{'accession': 'O43924', 'component_descriptio...
#
#                    target_type  tax_id
# 0               SINGLE PROTEIN    9606
# 1  PROTEIN-PROTEIN INTERACTION    9606
# 2  PROTEIN-PROTEIN INTERACTION    9606
# 3              PROTEIN COMPLEX    9606
# 4  PROTEIN-PROTEIN INTERACTION    9606

# %% [markdown]
# **Reterive Bioactivity data for selected target**

# %%
selected_target = targets.target_chembl_id[3]
selected_target
# Out:
# 'CHEMBL5465393'

# %% [markdown]
# **Now retrieve only bioactivity data for target; **von Hippel-Lindau disease tumor suppressor/KRAS(CHEMBL5465393)** with reported IC 50  values in nM (nanomolar) unit.**

# %%
activity = new_client.activity
results = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df1 = pd.DataFrame.from_dict(results)
df1.head(5)
# Out:
#   action_type activity_comment  activity_id activity_properties  \
# 0        None             None     18978436                  []
# 1        None             None     18978437                  []
# 2        None             None     18978438                  []
# 3        None             None     18978439                  []
# 4        None             None     18978440                  []
#
#   assay_chembl_id                                  assay_description  \
# 0   CHEMBL4338721  Inhibition of human N-terminal GST-tagged K-Ra...
# 1   CHEMBL4338721  Inhibition of human N-terminal GST-tagged K-Ra...
# 2   CHEMBL4338721  Inhibition of human N-terminal GST-tagged K-Ra...
# 3   CHEMBL4338721  Inhibition of human N-terminal GST-tagged K-Ra...
# 4   CHEMBL4338721  Inhibition of human N-terminal GST-tagged K-Ra...
#
#   assay_type assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0          B                  P01116                   G12C  BAO_0000190  ...
# 1          B                  P01116                   G12C  BAO_0000190  ...
# 2          B                  P01116                   G12C  BAO_0000190  ...
# 3          B                  P01116                   G12C  BAO_0000190  ...
# 4          B                  P01116                   G12C  BAO_0000190  ...
#
#   target_organism target_pref_name target_tax_id text_value  toid  type units  \
# 0    Homo sapiens        SOS1-KRAS          9606       None  None  IC50    uM
# 1    Homo sapiens        SOS1-KRAS          9606       None  None  IC50    uM
# 2    Homo sapiens        SOS1-KRAS          9606       None  None  IC50    uM
# 3    Homo sapiens        SOS1-KRAS          9606       None  None  IC50    uM
# 4    Homo sapiens        SOS1-KRAS          9606       None  None  IC50    uM
#
#      uo_units upper_value value
# 0  UO_0000065        None  1.07
# 1  UO_0000065        None  2.46
# 2  UO_0000065        None  1.14
# 3  UO_0000065        None  0.93
# 4  UO_0000065        None  2.06
#
# [5 rows x 46 columns]

# %%
df1.standard_type.unique()
# Out:
# array(['IC50'], dtype=object)

# %% [markdown]
# **Finally Save the resulting bioactivity data to a CSV file** **bioactivity_raw_data.csv**.

# %%
df1.to_csv('bioactivity_raw_data.csv', index=False)

# %% [markdown]
# **Now copy "bioactivity_raw_data.csv" file to Google Drive, in foler "data"**

# %%
! cp bioactivity_raw_data.csv "/content/gdrive/My Drive/Colab Notebooks/data"

# %%
! ls -l "/content/gdrive/My Drive/Colab Notebooks/data"
# Out:
# total 1220
# -rw------- 1 root root 820206 Jan 23 20:13 bioactivity_preprocessed_data.csv
# -rw------- 1 root root 428242 Jan 26 19:14 bioactivity_raw_data.csv

# %%
! head bioactivity_raw_data.csv
# Out:
# action_type,activity_comment,activity_id,activity_properties,assay_chembl_id,assay_description,assay_type,assay_variant_accession,assay_variant_mutation,bao_endpoint,bao_format,bao_label,canonical_smiles,data_validity_comment,data_validity_description,document_chembl_id,document_journal,document_year,ligand_efficiency,molecule_chembl_id,molecule_pref_name,parent_molecule_chembl_id,pchembl_value,potential_duplicate,qudt_units,record_id,relation,src_id,standard_flag,standard_relation,standard_text_value,standard_type,standard_units,standard_upper_value,standard_value,target_chembl_id,target_organism,target_pref_name,target_tax_id,text_value,toid,type,units,uo_units,upper_value,value
# ,,18978436,[],CHEMBL4338721,Inhibition of human N-terminal GST-tagged K-RasG12C mutant/human N-terminal His-tagged SOS1 preincubated for 2 mis followed by SOS1 addition and measured after 60 mins by HTRF assay,B,P01116,G12C,BAO_0000190,BAO_0000019,assay format,CCOc1cc2c(N[C@H](C)c3ccc(F)cc3)nc(C)nc2cn1,,,CHEMBL4334534,ACS Med Chem Lett,2020,"{'bei': '18.29', 'le': '0.34', 'lle': '1.93', 'sei': '9.96'}",CHEMBL4456281,,CHEMBL4456281,5.97,0,http://www.openphacts.org/units/Nanomolar,3165873,=,1,1,=,,IC50,nM,,1070.0,CHEMBL5465393,Homo sapiens,SOS1-KRAS,9606,,,IC50,uM,UO_0000065,,1.07
# ,,18978437,[],CHEMBL4338721,Inhibition of human N-terminal GST-tagged K-RasG12C mutant/human N-terminal His-tagged SOS1 preincubated for 2 mis followed by SOS1 addition and measured after 60 mins by HTRF assay,B,P01116,G12C,BAO_0000190,BAO_0000019,assay format,COc1cc2c(N[C@H](C)c3ccc(F)cc3)nc(C)nc2cn1,,,CHEMBL4334534,ACS Med Chem Lett,2020,"{'bei': '17.96', 'le': '0.33', 'lle': '1.96', 'sei': '9.36'}",CHEMBL4532624,,CHEMBL4532624,5.61,0,http://www.openphacts.org/units/Nanomolar,3165874,=,1,1,=,,IC50,nM,,2460.0,CHEMBL5465393,Homo sapiens,SOS1-KRAS,9606,,,IC50,uM,UO_0000065,,2.46
# ,,18978438,[],CHEMBL4338721,Inhibition of human N-terminal GST-tagged K-RasG12C mutant/human N-terminal His-tagged SOS1 preincubated for 2 mis followed by SOS1 addition and measured after 60 mins by HTRF assay,B,P01116,G12C,BAO_0000190,BAO_0000019,assay format,COCCOc1cc2c(N[C@H](C)c3ccc(F)cc3)nc(C)nc2cn1,,,CHEMBL4334534,ACS Med Chem Lett,2020,"{'bei': '16.68', 'le': '0.31', 'lle': '2.27', 'sei': '8.59'}",CHEMBL4445586,,CHEMBL4445586,5.94,0,http://www.openphacts.org/units/Nanomolar,3165875,=,1,1,=,,IC50,nM,,1140.0,CHEMBL5465393,Homo sapiens,SOS1-KRAS,9606,,,IC50,uM,UO_0000065,,1.14
# ,,18978439,[],CHEMBL4338721,Inhibition of human N-terminal GST-tagged K-RasG12C mutant/human N-terminal His-tagged SOS1 preincubated for 2 mis followed by SOS1 addition and measured after 60 mins by HTRF assay,B,P01116,G12C,BAO_0000190,BAO_0000019,assay format,CSc1cc2c(N[C@H](C)c3ccc(F)cc3)nc(C)nc2cn1,,,CHEMBL4334534,ACS Med Chem Lett,2020,"{'bei': '18.37', 'le': '0.36', 'lle': '1.66', 'sei': '11.90'}",CHEMBL4436731,,CHEMBL4436731,6.03,0,http://www.openphacts.org/units/Nanomolar,3165876,=,1,1,=,,IC50,nM,,930.0,CHEMBL5465393,Homo sapiens,SOS1-KRAS,9606,,,IC50,uM,UO_0000065,,0.93
# ,,18978440,[],CHEMBL4338721,Inhibition of human N-terminal GST-tagged K-RasG12C mutant/human N-terminal His-tagged SOS1 preincubated for 2 mis followed by SOS1 addition and measured after 60 mins by HTRF assay,B,P01116,G12C,BAO_0000190,BAO_0000019,assay format,CCOc1cc2c(N[C@H](C)c3ccccc3)nc(C)nc2cn1,,,CHEMBL4334534,ACS Med Chem Lett,2020,"{'bei': '18.44', 'le': '0.34', 'lle': '1.78', 'sei': '9.49'}",CHEMBL4545109,,CHEMBL4545109,5.69,0,http://www.openphacts.org/units/Nanomolar,3165877,=,1,1,=,,IC50,nM,,2060.0,CHEMBL5465393,Homo sapiens,SOS1-KRAS,9606,,,IC50,uM,UO_0000065,,2.06
# ,,18978441,[],CHEMBL4338721,Inhibition of human N-terminal GST-tagged K-RasG12C mutant/human N-terminal His-tagged SOS1 preincubated for 2 mis followed by SOS1 addition and measured after 60 mins by HTRF assay,B,P01116,G12C,BAO_0000190,BAO_0000019,assay format,CNCc1ccccc1-c1ccc(C(C)Nc2nc(C)nc3cnc(OCC4CCNC(=O)C4)cc23)s1,,,CHEMBL4334534,ACS Med Chem Lett,2020,"{'bei': '13.64', 'le': '0.26', 'lle': '2.19', 'sei': '6.97'}",CHEMBL4436932,,CHEMBL4436932,7.05,0,http://www.openphacts.org/units/Nanomolar,3165878,=,1,1,=,,IC50,nM,,90.0,CHEMBL5465393,Homo sapiens,SOS1-KRAS,9606,,,IC50,uM,UO_0000065,,0.09
# ,,18978442,[],CHEMBL4338721,Inhibition of human N-terminal GST-tagged K-RasG12C mutant/human N-terminal His-tagged SOS1 preincubated for 2 mis followed by SOS1 addition and measured after 60 mins by HTRF assay,B,P01116,G12C,BAO_0000190,BAO_0000019,assay format,CC(=O)NC1CCN(c2cc3c(NC(C)c4ccc(-c5ccccc5CN(C)C)s4)nc(C)nc3cn2)C1,,,CHEMBL4334534,ACS Med Chem Lett,2020,"{'bei': '14.42', 'le': '0.27', 'lle': '2.63', 'sei': '8.85'}",CHEMBL4556876,,CHEMBL4556876,7.64,0,http://www.openphacts.org/units/Nanomolar,3165879,=,1,1,=,,IC50,nM,,23.0,CHEMBL5465393,Homo sapiens,SOS1-KRAS,9606,,,IC50,uM,UO_0000065,,0.023
# ,,18978443,[],CHEMBL4338721,Inhibition of human N-terminal GST-tagged K-RasG12C mutant/human N-terminal His-tagged SOS1 preincubated for 2 mis followed by SOS1 addition and measured after 60 mins by HTRF assay,B,P01116,G12C,BAO_0000190,BAO_0000019,assay format,Cc1nc(NC(C)c2ccc(-c3ccccc3CN(C)C)s2)c2cc(N3CCNC(=O)C3)ncc2n1,,,CHEMBL4334534,ACS Med Chem Lett,2020,"{'bei': '15.06', 'le': '0.29', 'lle': '3.32', 'sei': '8.75'}",CHEMBL4591897,,CHEMBL4591897,7.55,0,http://www.openphacts.org/units/Nanomolar,3165880,=,1,1,=,,IC50,nM,,28.0,CHEMBL5465393,Homo sapiens,SOS1-KRAS,9606,,,IC50,uM,UO_0000065,,0.028
# ,,18978444,[],CHEMBL4338721,Inhibition of human N-terminal GST-tagged K-RasG12C mutant/human N-terminal His-tagged SOS1 preincubated for 2 mis followed by SOS1 addition and measured after 60 mins by HTRF assay,B,P01116,G12C,BAO_0000190,BAO_0000019,assay format,Cc1nc(NC(C)c2ccc(-c3ccccc3CN(C)C)s2)c2cc(N3CCN(Cc4cccnc4)CC3)ncc2n1,,,CHEMBL4334534,ACS Med Chem Lett,2020,"{'bei': '12.71', 'le': '0.24', 'lle': '1.35', 'sei': '10.03'}",CHEMBL4467637,,CHEMBL4467637,7.36,0,http://www.openphacts.org/units/Nanomolar,3165881,=,1,1,=,,IC50,nM,,44.0,CHEMBL5465393,Homo sapiens,SOS1-KRAS,9606,,,IC50,uM,UO_0000065,,0.044

# %% [markdown]
# # **Step 3: Bioactivity Data Retrieval (IC50)**
# **Retrieve bioactivity data (IC50) for the selected KRAS target.**

# %% [markdown]
# **Inspect Missing Values**

# %%
df1["standard_type"].isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# **Filter Rows with Valid Bioactivity Values**

# %%
df2 = df1[df1["standard_value"].notna()]
df2.head()
# Out:
#   action_type activity_comment  activity_id activity_properties  \
# 0        None             None     18978436                  []
# 1        None             None     18978437                  []
# 2        None             None     18978438                  []
# 3        None             None     18978439                  []
# 4        None             None     18978440                  []
#
#   assay_chembl_id                                  assay_description  \
# 0   CHEMBL4338721  Inhibition of human N-terminal GST-tagged K-Ra...
# 1   CHEMBL4338721  Inhibition of human N-terminal GST-tagged K-Ra...
# 2   CHEMBL4338721  Inhibition of human N-terminal GST-tagged K-Ra...
# 3   CHEMBL4338721  Inhibition of human N-terminal GST-tagged K-Ra...
# 4   CHEMBL4338721  Inhibition of human N-terminal GST-tagged K-Ra...
#
#   assay_type assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0          B                  P01116                   G12C  BAO_0000190  ...
# 1          B                  P01116                   G12C  BAO_0000190  ...
# 2          B                  P01116                   G12C  BAO_0000190  ...
# 3          B                  P01116                   G12C  BAO_0000190  ...
# 4          B                  P01116                   G12C  BAO_0000190  ...
#
#   target_organism target_pref_name target_tax_id text_value  toid  type units  \
# 0    Homo sapiens        SOS1-KRAS          9606       None  None  IC50    uM
# 1    Homo sapiens        SOS1-KRAS          9606       None  None  IC50    uM
# 2    Homo sapiens        SOS1-KRAS          9606       None  None  IC50    uM
# 3    Homo sapiens        SOS1-KRAS          9606       None  None  IC50    uM
# 4    Homo sapiens        SOS1-KRAS          9606       None  None  IC50    uM
#
#      uo_units upper_value value
# 0  UO_0000065        None  1.07
# 1  UO_0000065        None  2.46
# 2  UO_0000065        None  1.14
# 3  UO_0000065        None  0.93
# 4  UO_0000065        None  2.06
#
# [5 rows x 46 columns]

# %% [markdown]
# **Assign Bioactivity Classes**
# Define active, intermediate, and inactive classes based on IC50 values.

# %%
bioactivity_class = []
for value in df2.standard_value:
    value = float(value)
    if value >= 10000:
        bioactivity_class.append("inactive")
    elif value <= 1000:
        bioactivity_class.append("active")
    else:
        bioactivity_class.append("intermediate")

# %% [markdown]
# **Extract Relevant Columns**

# %%
molecule_ids = df2.molecule_chembl_id.tolist()
canonical_smiles = df2.canonical_smiles.tolist()
standard_values = df2.standard_value.tolist()

# %%
data = list(zip(
    molecule_ids,
    canonical_smiles,
    standard_values,
        bioactivity_class,
))

# %% [markdown]
# **Create Preprocessed bioactivity Dataset**

# %%
df3 = pd.DataFrame(
    data,
    columns=[
        "molecule_chembl_id",
        "canonical_smiles",
        "standard_value",
        "bioactivity_class",
    ]
)
df3.head()
# Out:
#   molecule_chembl_id                              canonical_smiles  \
# 0      CHEMBL4456281    CCOc1cc2c(N[C@H](C)c3ccc(F)cc3)nc(C)nc2cn1
# 1      CHEMBL4532624     COc1cc2c(N[C@H](C)c3ccc(F)cc3)nc(C)nc2cn1
# 2      CHEMBL4445586  COCCOc1cc2c(N[C@H](C)c3ccc(F)cc3)nc(C)nc2cn1
# 3      CHEMBL4436731     CSc1cc2c(N[C@H](C)c3ccc(F)cc3)nc(C)nc2cn1
# 4      CHEMBL4545109       CCOc1cc2c(N[C@H](C)c3ccccc3)nc(C)nc2cn1
#
#   standard_value bioactivity_class
# 0         1070.0      intermediate
# 1         2460.0      intermediate
# 2         1140.0      intermediate
# 3          930.0            active
# 4         2060.0      intermediate

# %% [markdown]
# **Remove Compounds without Valid SMILES**. Drop rows with **NaN**, **empty** or **None** SMILES values.

# %%
df3 = df3.dropna(subset=["canonical_smiles"])
df3 = df3[df3["canonical_smiles"].str.lower() != "none"]
df3 = df3[df3["canonical_smiles"].str.strip() != ""]
df3.head()
# Out:
#   molecule_chembl_id                              canonical_smiles  \
# 0      CHEMBL4456281    CCOc1cc2c(N[C@H](C)c3ccc(F)cc3)nc(C)nc2cn1
# 1      CHEMBL4532624     COc1cc2c(N[C@H](C)c3ccc(F)cc3)nc(C)nc2cn1
# 2      CHEMBL4445586  COCCOc1cc2c(N[C@H](C)c3ccc(F)cc3)nc(C)nc2cn1
# 3      CHEMBL4436731     CSc1cc2c(N[C@H](C)c3ccc(F)cc3)nc(C)nc2cn1
# 4      CHEMBL4545109       CCOc1cc2c(N[C@H](C)c3ccccc3)nc(C)nc2cn1
#
#   standard_value bioactivity_class
# 0         1070.0      intermediate
# 1         2460.0      intermediate
# 2         1140.0      intermediate
# 3          930.0            active
# 4         2060.0      intermediate

# %% [markdown]
# **Save Preprocessed Bioactivity Data.** Save the cleaned dataset to CSV and copy to Google Drive.

# %%
df3.to_csv("bioactivity_preprocessed_data.csv", index=False)

# !cp bioactivity_preprocessed_data.csv "/content/gdrive/My Drive/Colab Notebooks/data"
# !ls "/content/gdrive/My Drive/Colab Notebooks/data"
# Out:
# bioactivity_preprocessed_data.csv  bioactivity_raw_data.csv

# %% [markdown]
# ## **End of Part 1: Data Collection and Curation**

# %%
from google.colab import drive
drive.mount('/content/drive')
